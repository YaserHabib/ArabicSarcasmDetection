# %%
import pandas as pd

# %%
def prepDatasets(dataset):
    if "sentiment" in dataset.columns:
        dataset = dataset.drop(["sentiment"], axis=1)
    dataset = dataset[["tweet", "dialect", "sarcasm"]]

    return dataset

# %%
def siftData(data, name):
    data = data.sample(frac=1)
    data = data.drop_duplicates(subset=["tweet"])
    data = data.dropna()
    data = data.reset_index(drop=True)
    data.to_csv(rf"..\{name}.csv", index=False)

    return data

# %%
augResult = pd.read_csv("augDataset.csv")
GPTResult = pd.read_csv("GPTDataset.csv")
originalDataset = pd.read_csv("originalCombined.csv")
backtransResult = pd.read_csv("backtransDataset.csv")
synonymrepResult = pd.read_csv("synonymrepDataset.csv")

# %%
augResult = prepDatasets(augResult.copy(deep=True))
GPTResult = prepDatasets(GPTResult.copy(deep=True))
originalDataset = prepDatasets(originalDataset.copy(deep=True))
backtransResult = prepDatasets(backtransResult.copy(deep=True))
synonymrepResult = prepDatasets(synonymrepResult.copy(deep=True))

# %%
print(originalDataset.info(), "\n")
print("\n", augResult.info(), "\n")
print("\n", backtransResult.info(), "\n")
print("\n", synonymrepResult.info(), "\n")
print("\n", GPTResult.info(), "\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19050 entries, 0 to 19049
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    19050 non-null  object
#  1   dialect  19050 non-null  object
#  2   sarcasm  19050 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 446.6+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5064 entries, 0 to 5063
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    5063 non-null   object
#  1   dialect  5064 non-null   object
#  2   sarcasm  5064 non-null   bool
# dtypes: bool(1), object(2)
# memory usage: 84.2+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2574 entries, 0 to 2573
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    2573 non-null   object
#  1   dialect  2574 non-null   object
#  2   sarcasm  2574 non-null   bool
# dtypes: bool(1), object(2)
# memory usage: 42.9+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3795 entries, 0 to 3794
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    3794 non-null   object
#  1   dialect  3795 non-null   object
#  2   sarcasm  3795 non-null   bool
# dtypes: bool(1), object(2)
# memory usage: 63.1+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4470 entries, 0 to 4469
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    4470 non-null   object
#  1   dialect  4470 non-null   object
#  2   sarcasm  4470 non-null   bool
# dtypes: bool(1), object(2)
# memory usage: 74.3+ KB
#
#  None

# %%
augDataset = pd.concat([originalDataset, augResult])
GPTDataset = pd.concat([originalDataset, GPTResult])
fullDataset = pd.concat([originalDataset, augResult, GPTResult])
backtransDataset = pd.concat([originalDataset, backtransResult])
synonymrepDataset = pd.concat([originalDataset, synonymrepResult])
synGPTDataset = pd.concat([originalDataset, synonymrepResult, GPTResult])
backGPTDataset = pd.concat([originalDataset, backtransResult, GPTResult])

# %%
print(originalDataset.info(), "\n")
print("\n", backtransDataset.info(), "\n")
print("\n", synonymrepDataset.info(), "\n")
print("\n", GPTDataset.info(), "\n")
print("\n", augDataset.info(), "\n")
print("\n", synGPTDataset.info(), "\n")
print("\n", backGPTDataset.info(), "\n")
print("\n", fullDataset.info(), "\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19050 entries, 0 to 19049
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    19050 non-null  object
#  1   dialect  19050 non-null  object
#  2   sarcasm  19050 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 446.6+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 21624 entries, 0 to 2573
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    21623 non-null  object
#  1   dialect  21624 non-null  object
#  2   sarcasm  21624 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 675.8+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 22845 entries, 0 to 3794
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    22844 non-null  object
#  1   dialect  22845 non-null  object
#  2   sarcasm  22845 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 713.9+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 23520 entries, 0 to 4469
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    23520 non-null  object
#  1   dialect  23520 non-null  object
#  2   sarcasm  23520 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 735.0+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 24114 entries, 0 to 5063
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    24113 non-null  object
#  1   dialect  24114 non-null  object
#  2   sarcasm  24114 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 753.6+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 27315 entries, 0 to 4469
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    27314 non-null  object
#  1   dialect  27315 non-null  object
#  2   sarcasm  27315 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 853.6+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 26094 entries, 0 to 4469
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    26093 non-null  object
#  1   dialect  26094 non-null  object
#  2   sarcasm  26094 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 815.4+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 28584 entries, 0 to 4469
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    28583 non-null  object
#  1   dialect  28584 non-null  object
#  2   sarcasm  28584 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 893.2+ KB
#
#  None

# %%
GPTDataset = siftData(GPTDataset.copy(deep=True), "GPT Dataset")
fullDataset = siftData(fullDataset.copy(deep=True), "full Dataset")
augDataset = siftData(augDataset.copy(deep=True), "augmented Dataset")
synGPTDataset = siftData(synGPTDataset.copy(deep=True), "synGPT Dataset")
backGPTDataset = siftData(backGPTDataset.copy(deep=True), "backGPT Dataset")
synonymrepDataset = siftData(synonymrepDataset.copy(deep=True), "synrep Dataset")
backtransDataset = siftData(backtransDataset.copy(deep=True), "backtrans Dataset")

# %%
print(originalDataset.info(), "\n")
print("\n", backtransDataset.info(), "\n")
print("\n", synonymrepDataset.info(), "\n")
print("\n", GPTDataset.info(), "\n")
print("\n", augDataset.info(), "\n")
print("\n", synGPTDataset.info(), "\n")
print("\n", backGPTDataset.info(), "\n")
print("\n", fullDataset.info(), "\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19050 entries, 0 to 19049
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    19050 non-null  object
#  1   dialect  19050 non-null  object
#  2   sarcasm  19050 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 446.6+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20910 entries, 0 to 20909
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    20910 non-null  object
#  1   dialect  20910 non-null  object
#  2   sarcasm  20910 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 490.2+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22130 entries, 0 to 22129
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    22130 non-null  object
#  1   dialect  22130 non-null  object
#  2   sarcasm  22130 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 518.8+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22795 entries, 0 to 22794
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    22795 non-null  object
#  1   dialect  22795 non-null  object
#  2   sarcasm  22795 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 534.4+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23399 entries, 0 to 23398
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    23399 non-null  object
#  1   dialect  23399 non-null  object
#  2   sarcasm  23399 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 548.5+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26588 entries, 0 to 26587
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    26588 non-null  object
#  1   dialect  26588 non-null  object
#  2   sarcasm  26588 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 623.3+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25368 entries, 0 to 25367
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    25368 non-null  object
#  1   dialect  25368 non-null  object
#  2   sarcasm  25368 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 594.7+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27857 entries, 0 to 27856
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    27857 non-null  object
#  1   dialect  27857 non-null  object
#  2   sarcasm  27857 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 653.0+ KB
#
#  None
