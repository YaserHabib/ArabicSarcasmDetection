# %%
import pandas as pd

# %%
def siftData(data, name):
    data = data.sample(frac=1)
    data = data.drop_duplicates(subset=["tweet"])
    data = data.dropna()
    data = data.reset_index(drop=True)
    data.to_csv(rf"..\{name}.csv", index=False)

    return data

# %%
augResult = pd.read_csv("augResult.csv")
GPTResult = pd.read_csv("GPTResult.csv")
backtransResult = pd.read_csv("backtransResult.csv")
synonymrepResult = pd.read_csv("synonymrepResult.csv")
originalDataset = pd.read_csv(r"https://raw.githubusercontent.com/iabufarha/ArSarcasm-v2/main/ArSarcasm-v2/training_data.csv")

# %%
print(originalDataset.info(), "\n")
print("\n", augResult.info(), "\n")
print("\n", backtransResult.info(), "\n")
print("\n", synonymrepResult.info(), "\n")
print("\n", GPTResult.info(), "\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12548 entries, 0 to 12547
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet      12548 non-null  object
#  1   sarcasm    12548 non-null  bool
#  2   sentiment  12548 non-null  object
#  3   dialect    12548 non-null  object
# dtypes: bool(1), object(3)
# memory usage: 306.5+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2806 entries, 0 to 2805
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet      2805 non-null   object
#  1   dialect    2806 non-null   object
#  2   sentiment  2806 non-null   object
#  3   sarcasm    2806 non-null   bool
# dtypes: bool(1), object(3)
# memory usage: 68.6+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1427 entries, 0 to 1426
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet      1426 non-null   object
#  1   dialect    1427 non-null   object
#  2   sentiment  1427 non-null   object
#  3   sarcasm    1427 non-null   bool
# dtypes: bool(1), object(3)
# memory usage: 35.0+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2109 entries, 0 to 2108
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet      2108 non-null   object
#  1   dialect    2109 non-null   object
#  2   sentiment  2109 non-null   object
#  3   sarcasm    2109 non-null   bool
# dtypes: bool(1), object(3)
# memory usage: 51.6+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3266 entries, 0 to 3265
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet      3266 non-null   object
#  1   dialect    3266 non-null   object
#  2   sentiment  3266 non-null   object
#  3   sarcasm    3266 non-null   bool
# dtypes: bool(1), object(3)
# memory usage: 79.9+ KB
#
#  None

# %%
augDataset = pd.concat([originalDataset, augResult])
GPTDataset = pd.concat([originalDataset, GPTResult])
fullDataset = pd.concat([originalDataset, augResult, GPTResult])
backtransDataset = pd.concat([originalDataset, backtransResult])
synonymrepDataset = pd.concat([originalDataset, synonymrepResult])
synGPTDataset = pd.concat([originalDataset, synonymrepResult, GPTResult])
backGPTDataset = pd.concat([originalDataset, backtransResult, GPTResult])

# %%
print(originalDataset.info(), "\n")
print("\n", backtransDataset.info(), "\n")
print("\n", synonymrepDataset.info(), "\n")
print("\n", GPTDataset.info(), "\n")
print("\n", augDataset.info(), "\n")
print("\n", synGPTDataset.info(), "\n")
print("\n", backGPTDataset.info(), "\n")
print("\n", fullDataset.info(), "\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12548 entries, 0 to 12547
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet      12548 non-null  object
#  1   sarcasm    12548 non-null  bool
#  2   sentiment  12548 non-null  object
#  3   dialect    12548 non-null  object
# dtypes: bool(1), object(3)
# memory usage: 306.5+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 13975 entries, 0 to 1426
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet      13974 non-null  object
#  1   sarcasm    13975 non-null  bool
#  2   sentiment  13975 non-null  object
#  3   dialect    13975 non-null  object
# dtypes: bool(1), object(3)
# memory usage: 450.4+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 14657 entries, 0 to 2108
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet      14656 non-null  object
#  1   sarcasm    14657 non-null  bool
#  2   sentiment  14657 non-null  object
#  3   dialect    14657 non-null  object
# dtypes: bool(1), object(3)
# memory usage: 472.3+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 15814 entries, 0 to 3265
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet      15814 non-null  object
#  1   sarcasm    15814 non-null  bool
#  2   sentiment  15814 non-null  object
#  3   dialect    15814 non-null  object
# dtypes: bool(1), object(3)
# memory usage: 509.6+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 15354 entries, 0 to 2805
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet      15353 non-null  object
#  1   sarcasm    15354 non-null  bool
#  2   sentiment  15354 non-null  object
#  3   dialect    15354 non-null  object
# dtypes: bool(1), object(3)
# memory usage: 494.8+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 17923 entries, 0 to 3265
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet      17922 non-null  object
#  1   sarcasm    17923 non-null  bool
#  2   sentiment  17923 non-null  object
#  3   dialect    17923 non-null  object
# dtypes: bool(1), object(3)
# memory usage: 577.6+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 17241 entries, 0 to 3265
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet      17240 non-null  object
#  1   sarcasm    17241 non-null  bool
#  2   sentiment  17241 non-null  object
#  3   dialect    17241 non-null  object
# dtypes: bool(1), object(3)
# memory usage: 555.6+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 18620 entries, 0 to 3265
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet      18619 non-null  object
#  1   sarcasm    18620 non-null  bool
#  2   sentiment  18620 non-null  object
#  3   dialect    18620 non-null  object
# dtypes: bool(1), object(3)
# memory usage: 600.1+ KB
#
#  None

# %%
GPTDataset = siftData(GPTDataset.copy(deep=True), "GPT Dataset")
fullDataset = siftData(fullDataset.copy(deep=True), "full Dataset")
augDataset = siftData(augDataset.copy(deep=True), "augmented Dataset")
synGPTDataset = siftData(synGPTDataset.copy(deep=True), "synGPT Dataset")
backGPTDataset = siftData(backGPTDataset.copy(deep=True), "backGPT Dataset")
synonymrepDataset = siftData(synonymrepDataset.copy(deep=True), "synrep Dataset")
backtransDataset = siftData(backtransDataset.copy(deep=True), "backtrans Dataset")

# %%
print(originalDataset.info(), "\n")
print("\n", backtransDataset.info(), "\n")
print("\n", synonymrepDataset.info(), "\n")
print("\n", GPTDataset.info(), "\n")
print("\n", augDataset.info(), "\n")
print("\n", synGPTDataset.info(), "\n")
print("\n", backGPTDataset.info(), "\n")
print("\n", fullDataset.info(), "\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12548 entries, 0 to 12547
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet      12548 non-null  object
#  1   sarcasm    12548 non-null  bool
#  2   sentiment  12548 non-null  object
#  3   dialect    12548 non-null  object
# dtypes: bool(1), object(3)
# memory usage: 306.5+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13913 entries, 0 to 13912
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet      13913 non-null  object
#  1   sarcasm    13913 non-null  bool
#  2   sentiment  13913 non-null  object
#  3   dialect    13913 non-null  object
# dtypes: bool(1), object(3)
# memory usage: 339.8+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14595 entries, 0 to 14594
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet      14595 non-null  object
#  1   sarcasm    14595 non-null  bool
#  2   sentiment  14595 non-null  object
#  3   dialect    14595 non-null  object
# dtypes: bool(1), object(3)
# memory usage: 356.5+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15742 entries, 0 to 15741
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet      15742 non-null  object
#  1   sarcasm    15742 non-null  bool
#  2   sentiment  15742 non-null  object
#  3   dialect    15742 non-null  object
# dtypes: bool(1), object(3)
# memory usage: 384.5+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15292 entries, 0 to 15291
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet      15292 non-null  object
#  1   sarcasm    15292 non-null  bool
#  2   sentiment  15292 non-null  object
#  3   dialect    15292 non-null  object
# dtypes: bool(1), object(3)
# memory usage: 373.5+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17850 entries, 0 to 17849
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet      17850 non-null  object
#  1   sarcasm    17850 non-null  bool
#  2   sentiment  17850 non-null  object
#  3   dialect    17850 non-null  object
# dtypes: bool(1), object(3)
# memory usage: 435.9+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17168 entries, 0 to 17167
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet      17168 non-null  object
#  1   sarcasm    17168 non-null  bool
#  2   sentiment  17168 non-null  object
#  3   dialect    17168 non-null  object
# dtypes: bool(1), object(3)
# memory usage: 419.3+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18547 entries, 0 to 18546
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet      18547 non-null  object
#  1   sarcasm    18547 non-null  bool
#  2   sentiment  18547 non-null  object
#  3   dialect    18547 non-null  object
# dtypes: bool(1), object(3)
# memory usage: 452.9+ KB
#
#  None
