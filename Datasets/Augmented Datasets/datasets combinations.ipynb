# %%
import pandas as pd

# %%
def prepDatasets(dataset):
    if "sentiment" in dataset.columns:
        dataset = dataset.drop(["sentiment"], axis=1)
    dataset = dataset[["tweet", "dialect", "sarcasm"]]

    return dataset

# %%
def siftData(data, name):
    data = data.sample(frac=1)
    data = data.drop_duplicates(subset=["tweet"])
    data = data.dropna()
    data = data.reset_index(drop=True)
    data.to_csv(rf"..\{name}.csv", index=False)

    return data

# %%
augResult = pd.read_csv("augDataset.csv")
GPTResult = pd.read_csv("GPTDataset.csv")
originalDataset = pd.read_csv("../originalCombined.csv")
backtransResult = pd.read_csv("backtransDataset.csv")
synonymrepResult = pd.read_csv("synonymrepDataset.csv")

# %%
augResult = prepDatasets(augResult.copy(deep=True))
GPTResult = prepDatasets(GPTResult.copy(deep=True))
originalDataset = prepDatasets(originalDataset.copy(deep=True))
backtransResult = prepDatasets(backtransResult.copy(deep=True))
synonymrepResult = prepDatasets(synonymrepResult.copy(deep=True))

# %%
print(originalDataset.info(), "\n")
print("\n", augResult.info(), "\n")
print("\n", backtransResult.info(), "\n")
print("\n", synonymrepResult.info(), "\n")
print("\n", GPTResult.info(), "\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20478 entries, 0 to 20477
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    20478 non-null  object
#  1   dialect  20478 non-null  object
#  2   sarcasm  20478 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 480.1+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9198 entries, 0 to 9197
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    9198 non-null   object
#  1   dialect  9198 non-null   object
#  2   sarcasm  9198 non-null   bool
# dtypes: bool(1), object(2)
# memory usage: 152.8+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4608 entries, 0 to 4607
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    4608 non-null   object
#  1   dialect  4608 non-null   object
#  2   sarcasm  4608 non-null   bool
# dtypes: bool(1), object(2)
# memory usage: 76.6+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4646 entries, 0 to 4645
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    4646 non-null   object
#  1   dialect  4646 non-null   object
#  2   sarcasm  4646 non-null   bool
# dtypes: bool(1), object(2)
# memory usage: 77.3+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4470 entries, 0 to 4469
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    4470 non-null   object
#  1   dialect  4470 non-null   object
#  2   sarcasm  4470 non-null   bool
# dtypes: bool(1), object(2)
# memory usage: 74.3+ KB
#
#  None

# %%
augDataset = pd.concat([originalDataset, augResult])
GPTDataset = pd.concat([originalDataset, GPTResult])
fullDataset = pd.concat([originalDataset, augResult, GPTResult])
backtransDataset = pd.concat([originalDataset, backtransResult])
synonymrepDataset = pd.concat([originalDataset, synonymrepResult])
synGPTDataset = pd.concat([originalDataset, synonymrepResult, GPTResult])
backGPTDataset = pd.concat([originalDataset, backtransResult, GPTResult])

# %%
print(originalDataset.info(), "\n")
print("\n", backtransDataset.info(), "\n")
print("\n", synonymrepDataset.info(), "\n")
print("\n", GPTDataset.info(), "\n")
print("\n", augDataset.info(), "\n")
print("\n", synGPTDataset.info(), "\n")
print("\n", backGPTDataset.info(), "\n")
print("\n", fullDataset.info(), "\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20478 entries, 0 to 20477
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    20478 non-null  object
#  1   dialect  20478 non-null  object
#  2   sarcasm  20478 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 480.1+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 25086 entries, 0 to 4607
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    25086 non-null  object
#  1   dialect  25086 non-null  object
#  2   sarcasm  25086 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 783.9+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 25124 entries, 0 to 4645
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    25124 non-null  object
#  1   dialect  25124 non-null  object
#  2   sarcasm  25124 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 785.1+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 24948 entries, 0 to 4469
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    24948 non-null  object
#  1   dialect  24948 non-null  object
#  2   sarcasm  24948 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 779.6+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 29676 entries, 0 to 9197
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    29676 non-null  object
#  1   dialect  29676 non-null  object
#  2   sarcasm  29676 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 927.4+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 29594 entries, 0 to 4469
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    29594 non-null  object
#  1   dialect  29594 non-null  object
#  2   sarcasm  29594 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 924.8+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 29556 entries, 0 to 4469
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    29556 non-null  object
#  1   dialect  29556 non-null  object
#  2   sarcasm  29556 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 923.6+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 34146 entries, 0 to 4469
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    34146 non-null  object
#  1   dialect  34146 non-null  object
#  2   sarcasm  34146 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 1.0+ MB
#
#  None

# %%
GPTDataset = siftData(GPTDataset.copy(deep=True), "GPT Dataset")
fullDataset = siftData(fullDataset.copy(deep=True), "full Dataset")
augDataset = siftData(augDataset.copy(deep=True), "augmented Dataset")
synGPTDataset = siftData(synGPTDataset.copy(deep=True), "synGPT Dataset")
backGPTDataset = siftData(backGPTDataset.copy(deep=True), "backGPT Dataset")
synonymrepDataset = siftData(synonymrepDataset.copy(deep=True), "synrep Dataset")
backtransDataset = siftData(backtransDataset.copy(deep=True), "backtrans Dataset")

# %%
print(originalDataset.info(), "\n")
print("\n", backtransDataset.info(), "\n")
print("\n", synonymrepDataset.info(), "\n")
print("\n", GPTDataset.info(), "\n")
print("\n", augDataset.info(), "\n")
print("\n", synGPTDataset.info(), "\n")
print("\n", backGPTDataset.info(), "\n")
print("\n", fullDataset.info(), "\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20478 entries, 0 to 20477
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    20478 non-null  object
#  1   dialect  20478 non-null  object
#  2   sarcasm  20478 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 480.1+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25081 entries, 0 to 25080
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    25081 non-null  object
#  1   dialect  25081 non-null  object
#  2   sarcasm  25081 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 588.0+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25123 entries, 0 to 25122
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    25123 non-null  object
#  1   dialect  25123 non-null  object
#  2   sarcasm  25123 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 588.9+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24936 entries, 0 to 24935
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    24936 non-null  object
#  1   dialect  24936 non-null  object
#  2   sarcasm  24936 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 584.6+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29670 entries, 0 to 29669
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    29670 non-null  object
#  1   dialect  29670 non-null  object
#  2   sarcasm  29670 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 695.5+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29581 entries, 0 to 29580
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    29581 non-null  object
#  1   dialect  29581 non-null  object
#  2   sarcasm  29581 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 693.4+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29539 entries, 0 to 29538
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    29539 non-null  object
#  1   dialect  29539 non-null  object
#  2   sarcasm  29539 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 692.4+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34128 entries, 0 to 34127
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    34128 non-null  object
#  1   dialect  34128 non-null  object
#  2   sarcasm  34128 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 800.0+ KB
#
#  None

# %%
dataset = pd.read_csv(r"../originalCombined.csv")
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20478 entries, 0 to 20477
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    20478 non-null  object
#  1   dialect  20478 non-null  object
#  2   sarcasm  20478 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 480.1+ KB
