# %%
import pandas as pd

# %%
def prepDatasets(dataset):
    if "sentiment" in dataset.columns:
        dataset = dataset.drop(["sentiment"], axis=1)
    dataset = dataset[["tweet", "dialect", "sarcasm"]]

    return dataset

# %%
def siftData(data, name):
    data = data.sample(frac=1)
    data = data.drop_duplicates(subset=["tweet"])
    data = data.dropna()
    data = data.reset_index(drop=True)
    data.to_csv(rf"..\{name}.csv", index=False)

    return data

# %%
augResult = pd.read_csv("augDataset.csv")
GPTResult = pd.read_csv("GPTDataset.csv")
originalDataset = pd.read_csv("../originalCombined.csv")
backtransResult = pd.read_csv("backtransDataset.csv")
synonymrepResult = pd.read_csv("synonymrepDataset.csv")

# %%
augResult = prepDatasets(augResult.copy(deep=True))
GPTResult = prepDatasets(GPTResult.copy(deep=True))
originalDataset = prepDatasets(originalDataset.copy(deep=True))
backtransResult = prepDatasets(backtransResult.copy(deep=True))
synonymrepResult = prepDatasets(synonymrepResult.copy(deep=True))

# %%
print(originalDataset.info(), "\n")
print("\n", augResult.info(), "\n")
print("\n", backtransResult.info(), "\n")
print("\n", synonymrepResult.info(), "\n")
print("\n", GPTResult.info(), "\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18526 entries, 0 to 18525
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    18526 non-null  object
#  1   dialect  18526 non-null  object
#  2   sarcasm  18526 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 434.3+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7400 entries, 0 to 7399
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    7400 non-null   object
#  1   dialect  7400 non-null   object
#  2   sarcasm  7400 non-null   bool
# dtypes: bool(1), object(2)
# memory usage: 123.0+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3711 entries, 0 to 3710
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    3711 non-null   object
#  1   dialect  3711 non-null   object
#  2   sarcasm  3711 non-null   bool
# dtypes: bool(1), object(2)
# memory usage: 61.7+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3708 entries, 0 to 3707
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    3708 non-null   object
#  1   dialect  3708 non-null   object
#  2   sarcasm  3708 non-null   bool
# dtypes: bool(1), object(2)
# memory usage: 61.7+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4470 entries, 0 to 4469
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    4470 non-null   object
#  1   dialect  4470 non-null   object
#  2   sarcasm  4470 non-null   bool
# dtypes: bool(1), object(2)
# memory usage: 74.3+ KB
#
#  None

# %%
augDataset = pd.concat([originalDataset, augResult])
GPTDataset = pd.concat([originalDataset, GPTResult])
fullDataset = pd.concat([originalDataset, augResult, GPTResult])
backtransDataset = pd.concat([originalDataset, backtransResult])
synonymrepDataset = pd.concat([originalDataset, synonymrepResult])
synGPTDataset = pd.concat([originalDataset, synonymrepResult, GPTResult])
backGPTDataset = pd.concat([originalDataset, backtransResult, GPTResult])

# %%
print(originalDataset.info(), "\n")
print("\n", backtransDataset.info(), "\n")
print("\n", synonymrepDataset.info(), "\n")
print("\n", GPTDataset.info(), "\n")
print("\n", augDataset.info(), "\n")
print("\n", synGPTDataset.info(), "\n")
print("\n", backGPTDataset.info(), "\n")
print("\n", fullDataset.info(), "\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18526 entries, 0 to 18525
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    18526 non-null  object
#  1   dialect  18526 non-null  object
#  2   sarcasm  18526 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 434.3+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 22237 entries, 0 to 3710
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    22237 non-null  object
#  1   dialect  22237 non-null  object
#  2   sarcasm  22237 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 694.9+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 22234 entries, 0 to 3707
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    22234 non-null  object
#  1   dialect  22234 non-null  object
#  2   sarcasm  22234 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 694.8+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 22996 entries, 0 to 4469
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    22996 non-null  object
#  1   dialect  22996 non-null  object
#  2   sarcasm  22996 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 718.6+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 25926 entries, 0 to 7399
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    25926 non-null  object
#  1   dialect  25926 non-null  object
#  2   sarcasm  25926 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 810.2+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 26704 entries, 0 to 4469
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    26704 non-null  object
#  1   dialect  26704 non-null  object
#  2   sarcasm  26704 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 834.5+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 26707 entries, 0 to 4469
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    26707 non-null  object
#  1   dialect  26707 non-null  object
#  2   sarcasm  26707 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 834.6+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 30396 entries, 0 to 4469
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    30396 non-null  object
#  1   dialect  30396 non-null  object
#  2   sarcasm  30396 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 949.9+ KB
#
#  None

# %%
GPTDataset = siftData(GPTDataset.copy(deep=True), "GPT Dataset")
fullDataset = siftData(fullDataset.copy(deep=True), "full Dataset")
augDataset = siftData(augDataset.copy(deep=True), "augmented Dataset")
synGPTDataset = siftData(synGPTDataset.copy(deep=True), "synGPT Dataset")
backGPTDataset = siftData(backGPTDataset.copy(deep=True), "backGPT Dataset")
synonymrepDataset = siftData(synonymrepDataset.copy(deep=True), "synrep Dataset")
backtransDataset = siftData(backtransDataset.copy(deep=True), "backtrans Dataset")

# %%
print(originalDataset.info(), "\n")
print("\n", backtransDataset.info(), "\n")
print("\n", synonymrepDataset.info(), "\n")
print("\n", GPTDataset.info(), "\n")
print("\n", augDataset.info(), "\n")
print("\n", synGPTDataset.info(), "\n")
print("\n", backGPTDataset.info(), "\n")
print("\n", fullDataset.info(), "\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18526 entries, 0 to 18525
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    18526 non-null  object
#  1   dialect  18526 non-null  object
#  2   sarcasm  18526 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 434.3+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22048 entries, 0 to 22047
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    22048 non-null  object
#  1   dialect  22048 non-null  object
#  2   sarcasm  22048 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 516.9+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22045 entries, 0 to 22044
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    22045 non-null  object
#  1   dialect  22045 non-null  object
#  2   sarcasm  22045 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 516.8+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22795 entries, 0 to 22794
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    22795 non-null  object
#  1   dialect  22795 non-null  object
#  2   sarcasm  22795 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 534.4+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25737 entries, 0 to 25736
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    25737 non-null  object
#  1   dialect  25737 non-null  object
#  2   sarcasm  25737 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 603.3+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26503 entries, 0 to 26502
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    26503 non-null  object
#  1   dialect  26503 non-null  object
#  2   sarcasm  26503 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 621.3+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26506 entries, 0 to 26505
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    26506 non-null  object
#  1   dialect  26506 non-null  object
#  2   sarcasm  26506 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 621.4+ KB
#
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30195 entries, 0 to 30194
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tweet    30195 non-null  object
#  1   dialect  30195 non-null  object
#  2   sarcasm  30195 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 707.8+ KB
#
#  None
